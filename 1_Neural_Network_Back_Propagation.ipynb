# %% [markdown]
# <a href="https://colab.research.google.com/github/hari40009/Python-for-Data-Science/blob/main/1_Neural_Network_Back_Propagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
# !pip install keras

# %%
# Create your first MLP in Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load pima indians dataset
dataset = numpy.loadtxt("/content/pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=8,  activation='relu'))
model.add(Dense(8,  activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=250, batch_size=20)
# Out:
# Epoch 1/250
# 26/26 [==============================] - 14s 21ms/step - loss: 2.5545 - accuracy: 0.6444 - val_loss: 1.2339 - val_accuracy: 0.5236
# Epoch 2/250
# 26/26 [==============================] - 0s 3ms/step - loss: 1.1464 - accuracy: 0.5990 - val_loss: 1.0049 - val_accuracy: 0.6181
# Epoch 3/250
# 26/26 [==============================] - 0s 3ms/step - loss: 0.9694 - accuracy: 0.6212 - val_loss: 0.9378 - val_accuracy: 0.5827
# Epoch 4/250
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9406 - accuracy: 0.6035 - val_loss: 0.8658 - val_accuracy: 0.5984
# Epoch 5/250
# 26/26 [==============================] - 0s 3ms/step - loss: 0.8288 - accuracy: 0.6059 - val_loss: 0.8443 - val_accuracy: 0.6063
# Epoch 6/250
# 26/26 [==============================] - 0s 3ms/step - loss: 0.7774 - accuracy: 0.6232 - val_loss: 0.8278 - val_accuracy: 0.6063
# Epoch 7/250
# ...

# %%
# evaluate the model
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5191 - accuracy: 0.7461
# accuracy: 74.61%
